# %% [markdown]
# <a href="https://colab.research.google.com/github/uttam112/chaabi/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import GPT2TokenizerFast

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.3 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=5a62ea777c2f190a3aa1460feb7fd3fcabf21a22080193cdbe5a5030a2352f05
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings()
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 58.1 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader(file_path='/content/drive/MyDrive/bigBasketProducts.csv', encoding="utf-8", csv_args={'delimiter': ','})
data = loader.load()

# %%
from langchain.vectorstores import FAISS
db = FAISS.from_documents(data, embeddings)

# embeddings = OpenAIEmbeddings()
# vectorstore = FAISS.from_documents(data, embeddings)

# %%
import pickle
with open("/content/drive/MyDrive/embedding/chabbi.pkl", "wb") as f:
    pickle.dump(db,f)

# %%
#loading it from drive
import pickle
with open("/content/drive/MyDrive/embedding/chabbi.pkl", "rb") as f:
    db = pickle.load(f)

# %%
docs = db._similarity_search_with_relevance_scores("Give spicy product", k = 6)

# %%
print(docs[0][0].page_content)
# Out:
# index: 1332
# product: Dry Chilli Garlic Condiment
# category: Gourmet & World Food
# sub_category: Cooking & Baking Needs
# brand: SPICHI
# sale_price: 62.5
# market_price: 125
# type: Curry Paste, Coconut Milk
# rating: 5
# ...

# %%
print(docs[1][0].page_content)
# Out:
# index: 26394
# product: Hot Garlic Paste
# category: Gourmet & World Food
# sub_category: Cooking & Baking Needs
# brand: SPICHI
# sale_price: 62.5
# market_price: 125
# type: Curry Paste, Coconut Milk
# rating:
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferWindowMemory

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(temperature=0), chain_type="stuff")

# %%
query = "Are there any sweet and sour mixture?"
docs = db.similarity_search(query)
# print(docs)
chain.run(input_documents=docs, question=query)
# Out:
# ' Yes, there is a Sweet n Sour Mixture - Mint with an index of 20903.'

# %%
query = "give some spicy food item"
docs = db.similarity_search(query)
# print(docs)
chain.run(input_documents=docs, question=query)
# Out:
# ' Spice Liquid Red Chilli Drop, Badshah Red Chilly Powder, Spice Story Spicy Mint Sauce, Entree Sandwich Masala Spice Mix.'

# %%
query = "Among Spice Liquid Red Chilli Drop, Badshah Red Chilly Powder and Spice Story Spicy Mint Sauce which is cheapest?"
docs = db.similarity_search(query)
# print(docs)
chain.run(input_documents=docs, question=query)
# Out:
# ' Spice Liquid Red Chilli Drop is the cheapest at 145.'

# %%
query = "What is the price of Sewing Kit from Seven?"
docs = db.similarity_search(query)
# print(docs)
chain.run(input_documents=docs, question=query)
# Out:
# ' The price of the Sewing Kit from Seven is 165.'
